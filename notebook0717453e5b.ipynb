# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/forest-surfaces-evolution-in-romania-19902019/forest_surfaces_romania_en_1990_2019.csv

# %%
df = pd.read_csv('/kaggle/input/forest-surfaces-evolution-in-romania-19902019/forest_surfaces_romania_en_1990_2019.csv')

# %%
df.head(10)
# Out:
#   Category Region  Year                 Unit   Value
# 0    Total  TOTAL  1990   Thousands hectares  6371.0
# 1    Total  TOTAL  1991   Thousands hectares  6367.6
# 2    Total  TOTAL  1992   Thousands hectares  6368.2
# 3    Total  TOTAL  1993   Thousands hectares  6366.9
# 4    Total  TOTAL  1994   Thousands hectares  6369.0
# 5    Total  TOTAL  1995   Thousands hectares  6368.8
# 6    Total  TOTAL  1996   Thousands hectares  6365.7
# 7    Total  TOTAL  1997   Thousands hectares  6367.3
# 8    Total  TOTAL  1998   Thousands hectares  6367.1
# 9    Total  TOTAL  1999   Thousands hectares  6367.3

# %%
df.shape
# Out:
# (8111, 5)

# %%
pd.DataFrame(dict(df['Category'].value_counts()).items(),columns=['Category','Numbers'])
# Out:
#    Category  Numbers
# 0  Hardwood     1639
# 1      Wood     1639
# 2     Total     1639
# 3    Others     1625
# 4  Softwood     1569

# %%
import matplotlib.pyplot as plt

# %%
pd.DataFrame(df['Region'].value_counts().items(),columns=['Region','Occurence'])
# Out:
#                         Region  Occurence
# 0                          Olt        150
# 1                        Arges        150
# 2   Regiunea BUCURESTI - ILFOV        150
# 3                    Satu Mare        150
# 4                    Dambovita        150
# 5            Regiunea NORD-EST        150
# 6                        Sibiu        150
# 7                     Harghita        150
# 8                       Vaslui        150
# 9           Regiunea NORD-VEST        150
# 10                   Constanta        150
# 11                     Covasna        150
# 12                   Mehedinti        150
# 13                       Ilfov        150
# 14                       Salaj        150
# 15            Regiunea SUD-EST        150
# 16                        Arad        150
# 17                     Suceava        150
# 18           MACROREGIUNEA DOI        150
# 19           MACROREGIUNEA UNU        150
# 20                      Galati        150
# ...

# %%
len(df['Region'].value_counts())
# Out:
# 55

# %% [markdown]
# Let's explore about Categories

# %% [markdown]
# WOOD

# %%
df_wood = df[df['Category']=='Wood']

# %%
df_wood = df_wood[df_wood['Region'] != 'TOTAL']

# %%
plt.bar(df_wood['Year'],df_wood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('Wood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'Wood Forest Area v/s Years')

# %%
plt.scatter(df_wood['Year'],df_wood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('Wood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'Wood Forest Area v/s Years')

# %%
plt.plot(df_wood['Year'],df_wood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('Wood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'Wood Forest Area v/s Years')

# %%
plt.hist2d(df_wood['Year'],df_wood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('Wood Forest Area v/s Years')
cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.kdeplot(df_wood['Value'])
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x = 'Region',y='Value',data = df_wood)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# CONCLUSION :
# 1.The Surface Area for Wood is increasing , only in the years 2007-2008 , there had been some decrement in the woods but after that there is rise the surface area for wood
# 2.MACROREGIUNEA TREI has the highest wood surface area in ROMANIA
# 3.Most Of the Wooden Forest Surface Area lies about 250 unit acres , with some exceptions ranging upto 2000 acres

# %% [markdown]
# # HARDWOOD

# %%
df_hardwood = df[df['Category']=='Hardwood']

# %%
df_hardwood = df_hardwood[df_hardwood['Region'] != 'TOTAL']

# %%
df_hardwood['Value'].plot()
plt.xlabel('Row Number')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.bar(df_hardwood['Year'],df_hardwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'HardWood Forest Area v/s Years')

# %%
plt.plot(df_hardwood['Year'],df_hardwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'HardWood Forest Area v/s Years')

# %%
plt.scatter(df_hardwood['Year'],df_hardwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'HardWood Forest Area v/s Years')

# %%
plt.hist2d(df_hardwood['Year'],df_hardwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.kdeplot(df_hardwood['Value'])
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x = 'Region',y='Value',data = df_hardwood)
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x = 'Year',y='Value',data = df_hardwood)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# CONCLUSIONS:
# 1.2001-02 and 2005-06 had least while around 2020 has the masximun surface are for hardwood
# 2.MACROREGIUNEA PATRU has the highest share of Hard Wood Area
# 3.Most of the hardwood trees have area between 100-200 unit acre

# %% [markdown]
# # SOFTWOOD

# %%
df_softwood = df[df['Category']=='Softwood']
df_softwood = df_softwood[df_softwood['Region'] != 'TOTAL']

# %%
df_softwood['Value'].plot()
plt.xlabel('Row Number')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
df_softwood['Region'][3330],df_softwood['Value'][3330],df['Year'][3330]
#most surface are is 875ish
#most productive are is MACROREGIUNEA UNU
#most productive year is 2012
# Out:
# ('MACROREGIUNEA UNU', 875.0, 2012)

# %%
plt.bar(df_softwood['Year'],df_softwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'HardWood Forest Area v/s Years')

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x = 'Year',y='Value',data = df_softwood)
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x = 'Region',y='Value',data = df_softwood)
plt.xticks(rotation = 90)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.kdeplot(df_softwood['Value'])
plt.xticks(rotation = 90)
plt.show()

# %%
plt.plot(df_softwood['Year'],df_softwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'HardWood Forest Area v/s Years')

# %%
plt.scatter(df_softwood['Year'],df_softwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
# Out:
# Text(0.5, 1.0, 'HardWood Forest Area v/s Years')

# %%
plt.hist2d(df_softwood['Year'],df_softwood['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('HardWood Forest Area v/s Years')
cbar = plt.colorbar()
cbar.ax.set_ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# Now we will look at the dataset at whole without any categories , let's explore it !!!

# %%
df['Value'].plot()
plt.xlabel('Row Number')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')

# %%
plt.bar(df['Year'],df['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title(' Area v/s Years')
# Out:
# Text(0.5, 1.0, ' Area v/s Years')

# %% [markdown]
# Value is on a continous growth throughout the years

# %%
plt.plot(df['Year'],df['Value'])
plt.xlabel('year')
plt.ylabel('Value')
plt.title('Area v/s Years')
# Out:
# Text(0.5, 1.0, 'Area v/s Years')

# %% [markdown]
# Most of the area in range of about 500 unit acres , with some ranging at 6000 unit acres

# %%
import seaborn as sns
plt.figure(figsize = (15,6))
sns.barplot(x = 'Region',y='Value',data = df)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# MACROREGIUNEA UNU , MACROREGIUNEA PATRU and MACROREGIUNEA DOI are the regions with vast surface areas of forest

# %% [markdown]
# # PREDICTING SURFACE AREA IN UPCOMING YEARS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8111 entries, 0 to 8110
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  8111 non-null   object
#  1   Region    8111 non-null   object
#  2   Year      8111 non-null   int64
#  3   Unit      8111 non-null   object
#  4   Value     8111 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 317.0+ KB

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['Category'] = label_encoder.fit_transform(df['Category'])
df['Region'] = label_encoder.fit_transform(df['Region'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8111 entries, 0 to 8110
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  8111 non-null   int64
#  1   Region    8111 non-null   int64
#  2   Year      8111 non-null   int64
#  3   Unit      8111 non-null   object
#  4   Value     8111 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 317.0+ KB

# %%
df.columns
# Out:
# Index(['Category', 'Region', 'Year', 'Unit', 'Value'], dtype='object')

# %%
x = df[['Category','Region','Year']]
y = df['Value']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=101)

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(x_train,y_train)
linear.score(x_test,y_test)
# Out:
# 0.04368430917672961

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor()
forest.fit(x_train,y_train)
forest.score(x_test,y_test)
# Out:
# 0.9999882772639405

# %% [markdown]
# Okay that's good enough accuracy for test data

# %%
predictions = forest.predict(x_test)

# %%
predictions
# Out:
# array([  1.665, 549.344,   1.582, ...,  93.782, 650.45 ,   5.584])

# %%
y_test = y_test.tolist()

# %%
plt.plot(y_test,predictions)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('ACTUAL VS PREDICTED')
# Out:
# Text(0.5, 1.0, 'ACTUAL VS PREDICTED')
